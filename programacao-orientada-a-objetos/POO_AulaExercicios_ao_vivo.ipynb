# %% [markdown]
# <a href="https://colab.research.google.com/github/dipucriodigital/engenharia-de-software/blob/main/programacao-orientada-a-objetos/POO_AulaExercicios_ao_vivo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Programação Orientada a Objetos
# ## Prof. Tatiana Escovedo
# ## Prof. Assistente Antonio Pedro
#
# ---
#
# ## Aula Prática de Exercícios

# %% [markdown]
# ## Prática 1)
#
# Vamos criar uma biblioteca de artigos científicos que armazene as publicações de autores e imprima a lista de artigos cadastrados em formato de citação bibliográfica, sendo que:
# - O **Autor** tem os atributos *nome_completo*, *nome_citacao*, *afiliacao*.
# - O **Artigo** tem *titulo*, *autor*, *ano_publicacao* (nesta primeira versão do programa, assuma que cada artigo só pode ter um autor).

# %%
class Autor:
    
    def __init__(self, nome_completo, nome_citacao, afiliacao):
        self.__nome_completo = nome_completo
        self.__nome_citacao = nome_citacao
        self.__afiliacao = afiliacao

    def consultar_nome_completo(self):
        return self.__nome_completo

    def consultar_nome_citacao(self):
        return self.__nome_citacao

    def consultar_afiliacao(self):
        return self.__afiliacao


class Artigo:
    
    def __init__(self, titulo, autor, ano_publicacao):
        self.__titulo = titulo
        self.__autor = autor
        self.__ano_publicacao = ano_publicacao

    # Depois podemos criar os métodos consulta se precisarmos, mas seria uma boa prática criar

    def imprimir_citacao(self):
        # T.ESCOVEDO, Desbravando o Python nas Empresas, 2023
        return("{}, {}, {}".format(self.__autor.consultar_nome_citacao(), self.__titulo, self.__ano_publicacao))


class BibliotecaArtigos:

    def __init__(self):
        self.__artigos = [] # a biblioteca ao ser criada virá com uma lista de artigos vazia

    def publicar_artigo(self, artigo):
        self.__artigos.append(artigo)

    def imprimir_catalogo_artigos(self):

        # Verificando se a lista de artigos está vazia
        if len(self.__artigos) == 0:
            print("\n### Não há artigos cadastrados na biblioteca!")
        else:
            # Apenas se a lista de artigos não for vazia
            print("\n### Artigos cadastrados na biblioteca:")
            for artigo in self.__artigos:
                print("-", artigo.imprimir_citacao())

# %%
# Instanciando a biblioteca
biblioteca = BibliotecaArtigos()

# Criando os autores
autor_1 = Autor("Tatiana Escovedo", "ESCOVEDO, T.", "PUC-Rio")
autor_2 = Autor("Marcos Kalinowski", "KALINOWSKI, M.", "PUC-Rio")
autor_3 = Autor("Sergio Lifschitz", "LIFSCHITZ, S.", "PUC-Rio")

# print(autor_1.consultar_nome_completo())

# Criando os artigos
artigo_1 = Artigo("Desbravando o Python nas Empresas", autor_1, 2023)
artigo_2 = Artigo("Desbravando a Engenharia de Software nas Empresas", autor_2, 2020)
artigo_3 = Artigo("Desbravando o BD nas Empresas", autor_3, 2018)

# print( artigo_1.imprimir_citacao() )

# Imprimindo o catálogo de artigos
biblioteca.imprimir_catalogo_artigos() # lista vazia!

# Publicando os artigos
biblioteca.publicar_artigo(artigo_1)
biblioteca.publicar_artigo(artigo_2)
biblioteca.publicar_artigo(artigo_3)

# Imprimindo o catálogo de artigos
biblioteca.imprimir_catalogo_artigos() # agora temos artigos na lista


#### EXTRAS

# Verificando o tipo de autor_1
# print(type(autor_1))
# Verificando se autor_1 é do tipo Autor
# print( isinstance(autor_1, Autor) )
# Out:
# ### Não há artigos cadastrados na biblioteca!
#
# ### Artigos cadastrados na biblioteca:
# - ESCOVEDO, T., Desbravando o Python nas Empresas, 2023
# - KALINOWSKI, M., Desbravando a Engenharia de Software nas Empresas, 2020
# - LIFSCHITZ, S., Desbravando o BD nas Empresas, 2018

# %% [markdown]
# ## Prática 2)
#
# Altere seu programa da Prática 1 para permitir que cada artigo tenha mais de um autor.

# %%
class Autor:
    
    def __init__(self, nome_completo, nome_citacao, afiliacao):
        self.__nome_completo = nome_completo
        self.__nome_citacao = nome_citacao
        self.__afiliacao = afiliacao

    def consultar_nome_completo(self):
        return self.__nome_completo

    def consultar_nome_citacao(self):
        return self.__nome_citacao

    def consultar_afiliacao(self):
        return self.__afiliacao


class Artigo:
    
    def __init__(self, titulo, autores, ano_publicacao):
        self.__titulo = titulo
        self.__autores = autores
        self.__ano_publicacao = ano_publicacao

    # Depois podemos criar os métodos consulta se precisarmos, mas seria uma boa prática criar

    def imprimir_citacao(self):
        # T.ESCOVEDO, M.KALINOWSKI, Desbravando o Python nas Empresas, 2023

        # variável que vai armazenar a lista de nomes citação de autores
        lista_de_autores = ""

        # para cada autor na lista de autores
        for autor in self.__autores:
            # vou concatenando o nome citação deste autor na variável acima
            lista_de_autores += autor.consultar_nome_citacao()
            # e concateno também uma vírgula e um espaço
            lista_de_autores += ", "

        # Desafio para casa: quem quiser pode substituir a última vírgula por um ponto!

        return("{}{}, {}.".format(lista_de_autores, self.__titulo, self.__ano_publicacao))


class BibliotecaArtigos:

    def __init__(self):
        self.__artigos = [] # a biblioteca ao ser criada virá com uma lista de artigos vazia

    def publicar_artigo(self, artigo):
        self.__artigos.append(artigo)

    def imprimir_catalogo_artigos(self):

        # Verificando se a lista de artigos está vazia
        if len(self.__artigos) == 0:
            print("\n### Não há artigos cadastrados na biblioteca!")
        else:
            # Apenas se a lista de artigos não for vazia
            print("\n### Artigos cadastrados na biblioteca:")
            for artigo in self.__artigos:
                print("-", artigo.imprimir_citacao())

# %%
# Instanciando a biblioteca
biblioteca = BibliotecaArtigos()

# Criando os autores
autor_1 = Autor("Tatiana Escovedo", "ESCOVEDO, T.", "PUC-Rio")
autor_2 = Autor("Marcos Kalinowski", "KALINOWSKI, M.", "PUC-Rio")
autor_3 = Autor("Sergio Lifschitz", "LIFSCHITZ, S.", "PUC-Rio")

# Criando os artigos
artigo_1 = Artigo("Desbravando o Python nas Empresas", [autor_1, autor_2], 2023)
artigo_2 = Artigo("Desbravando a Engenharia de Software nas Empresas", [autor_2], 2020)
artigo_3 = Artigo("Desbravando o BD nas Empresas", [autor_3, autor_1], 2018)
artigo_4 = Artigo("Artigo Bugado", [autor_1, autor_1], 2021) # OPA! Não deveria poder...

# Imprimindo o catálogo de artigos
biblioteca.imprimir_catalogo_artigos() # lista vazia!

# Publicando os artigos
biblioteca.publicar_artigo(artigo_1)
biblioteca.publicar_artigo(artigo_2)
biblioteca.publicar_artigo(artigo_3)
biblioteca.publicar_artigo(artigo_4)

# Imprimindo o catálogo de artigos
biblioteca.imprimir_catalogo_artigos() # agora temos artigos na lista

# DESAFIOS para quem quiser: 
# - não permitir autor repetido no mesmo artigo!
# - fazer validação de ano (por exemplo, 2030 é um ano inválido)
# - não deixar criar artigo com título vazio, ou sem autores, ou sem ano...
# - não deixar criar artigo com palavrões no título - será que já existe um dicionário?
# - em vez de criar autores/artigos na linha de comando, ler do teclado (input)
# Out:
# ### Não há artigos cadastrados na biblioteca!
#
# ### Artigos cadastrados na biblioteca:
# - ESCOVEDO, T., KALINOWSKI, M., Desbravando o Python nas Empresas, 2023.
# - KALINOWSKI, M., Desbravando a Engenharia de Software nas Empresas, 2020.
# - LIFSCHITZ, S., ESCOVEDO, T., Desbravando o BD nas Empresas, 2018.
# - ESCOVEDO, T., ESCOVEDO, T., Artigo Bugado, 2021.

# %% [markdown]
# # Bônus (fora do escopo da disciplina)!
#
# Conexão do Python com Banco de Dados SQLite

# %%
# importação da bibloteca do SQLite
import sqlite3 # importando sem alias

# criar conexão (irá criar ou abrir o arquivo .db do banco de dados)
con = sqlite3.connect("carsdb.db")

# o cursor permite percorrer os registros de um banco de dados
c = con.cursor()

# criar uma tabela
c.execute("create table if not exists cars(brand text, price text)")

# inserir registros na tabela
c.execute("insert into cars (brand, price) values ('bmw', 3000)")
c.execute("insert into cars (brand, price) values ('etios', 1000)")

# fazer o commit
con.commit()

# executar select * na tabela
result = c.execute("select * from cars")

# imprimir a primeira linha do select
#print(result.fetchone())

# imprimir TODAS as linhas da tabela
print(result.fetchall())

# fechar a conexão
con.close()
# Out:
# [('bmw', '3000'), ('etios', '1000'), ('bmw', '3000'), ('etios', '1000')]

# %% [markdown]
# ## Prática 3)
#
# Altere seu programa da Prática 2 tornando a classe **Artigo** abstrata, com o método *imprime_citacao* também abstrato. Crie na classe **Artigo** métodos públicos para permitir a consulta das variáveis de instância non-public nas subclasses.
#
# Crie duas subclasses de Artigo: **ArtigoConferencia** deve ter o atributo *local_evento* e **ArtigoPeriodico** o atributo *issn*. Implemente em cada uma das classes a sua versão específica do método *imprime_citacao*.
#
# Teste o programa criando artigos, adicionando-os à biblioteca e imprimindo a lista de artigos da biblioteca.

# %%
class Autor:
    
    def __init__(self, nome_completo, nome_citacao, afiliacao):
        self.__nome_completo = nome_completo
        self.__nome_citacao = nome_citacao
        self.__afiliacao = afiliacao

    def consultar_nome_completo(self):
        return self.__nome_completo

    def consultar_nome_citacao(self):
        return self.__nome_citacao

    def consultar_afiliacao(self):
        return self.__afiliacao


import abc

class Artigo(abc.ABC):
    
    def __init__(self, titulo, autores, ano_publicacao):
        self.__titulo = titulo
        self.__autores = autores
        self.__ano_publicacao = ano_publicacao

    def consultar_titulo(self):
        return self.__titulo

    def consultar_autores(self):
        return self.__autores

    def consultar_ano_publicacao(self):
        return self.__ano_publicacao
    
    @abc.abstractmethod
    def imprimir_citacao(self):
        pass



class ArtigoConferencia(Artigo):

    def __init__(self, titulo, autores, ano_publicacao, local_evento):
        Artigo.__init__(self, titulo, autores, ano_publicacao)
        self.__local_evento = local_evento

    def imprimir_citacao(self):
        # T.ESCOVEDO, M.KALINOWSKI, Desbravando o Python nas Empresas, 2023, Maceió

        # variável que vai armazenar a lista de nomes citação de autores
        lista_de_autores = ""

        # para cada autor na lista de autores
        for autor in self.consultar_autores():
            # vou concatenando o nome citação deste autor na variável acima
            lista_de_autores += autor.consultar_nome_citacao()
            # e concateno também uma vírgula e um espaço
            lista_de_autores += ", "

        # Desafio para casa: quem quiser pode substituir a última vírgula por um ponto!

        return("[Artigo de Conferência] {}{}, {}, {}.".format(lista_de_autores, self.consultar_titulo(), self.consultar_ano_publicacao(), self.__local_evento))


class ArtigoPeriodico(Artigo):

    def __init__(self, titulo, autores, ano_publicacao, issn):
        Artigo.__init__(self, titulo, autores, ano_publicacao)
        self.__issn = issn

    def imprimir_citacao(self):
        # T.ESCOVEDO, M.KALINOWSKI, Desbravando o Python nas Empresas, 2023, 4592-9034

        # variável que vai armazenar a lista de nomes citação de autores
        lista_de_autores = ""

        # para cada autor na lista de autores
        for autor in self.consultar_autores():
            # vou concatenando o nome citação deste autor na variável acima
            lista_de_autores += autor.consultar_nome_citacao()
            # e concateno também uma vírgula e um espaço
            lista_de_autores += ", "

        # Desafio para casa: quem quiser pode substituir a última vírgula por um ponto!

        return("[Artigo de Periódico] {}{}, {}, {}.".format(lista_de_autores, self.consultar_titulo(), self.consultar_ano_publicacao(), self.__issn))


class BibliotecaArtigos:

    def __init__(self):
        self.__artigos = [] # a biblioteca ao ser criada virá com uma lista de artigos vazia

    def publicar_artigo(self, artigo):
        self.__artigos.append(artigo)

    def imprimir_catalogo_artigos(self):

        # Verificando se a lista de artigos está vazia
        if len(self.__artigos) == 0:
            print("\n### Não há artigos cadastrados na biblioteca!")
        else:
            # Apenas se a lista de artigos não for vazia
            print("\n### Artigos cadastrados na biblioteca:")
            for artigo in self.__artigos:
                print("-", artigo.imprimir_citacao())

# %%
# Instanciando a biblioteca
biblioteca = BibliotecaArtigos()

# Criando os autores
autor_1 = Autor("Tatiana Escovedo", "ESCOVEDO, T.", "PUC-Rio")
autor_2 = Autor("Marcos Kalinowski", "KALINOWSKI, M.", "PUC-Rio")
autor_3 = Autor("Sergio Lifschitz", "LIFSCHITZ, S.", "PUC-Rio")

# Criando os artigos
artigo_1 = ArtigoConferencia("Desbravando o Python nas Empresas", [autor_1, autor_2], 2023, "Maceió")
artigo_2 = ArtigoConferencia("Desbravando a Engenharia de Software nas Empresas", [autor_2], 2020, "Rio de Janeiro")
artigo_3 = ArtigoPeriodico("Desbravando o BD nas Empresas", [autor_3, autor_1], 2018, "2344-8778")

# Imprimindo o catálogo de artigos
biblioteca.imprimir_catalogo_artigos() # lista vazia!

# Publicando os artigos
biblioteca.publicar_artigo(artigo_1)
biblioteca.publicar_artigo(artigo_2)
biblioteca.publicar_artigo(artigo_3)

# Imprimindo o catálogo de artigos
biblioteca.imprimir_catalogo_artigos() # agora temos artigos na lista

# Checando os tipos
print(type(artigo_1))
print(type(artigo_3))
# Out:
# ### Não há artigos cadastrados na biblioteca!
#
# ### Artigos cadastrados na biblioteca:
# - [Artigo de Conferência] ESCOVEDO, T., KALINOWSKI, M., Desbravando o Python nas Empresas, 2023, Maceió.
# - [Artigo de Conferência] KALINOWSKI, M., Desbravando a Engenharia de Software nas Empresas, 2020, Rio de Janeiro.
# - [Artigo de Periódico] LIFSCHITZ, S., ESCOVEDO, T., Desbravando o BD nas Empresas, 2018, 2344-8778.
# <class '__main__.ArtigoConferencia'>
# <class '__main__.ArtigoPeriodico'>

# %% [markdown]
# ## Prática 4)
#
# Altere seu programa da Prática 3 para:
# - permitir saber qual é o artigo com o maior número de autores
# - dado um autor, saber quais artigos ele publicou

# %%
class Autor:
    
    def __init__(self, nome_completo, nome_citacao, afiliacao):
        self.__nome_completo = nome_completo
        self.__nome_citacao = nome_citacao
        self.__afiliacao = afiliacao

    def consultar_nome_completo(self):
        return self.__nome_completo

    def consultar_nome_citacao(self):
        return self.__nome_citacao

    def consultar_afiliacao(self):
        return self.__afiliacao


import abc

class Artigo(abc.ABC):
    
    def __init__(self, titulo, autores, ano_publicacao):
        self.__titulo = titulo
        self.__autores = autores
        self.__ano_publicacao = ano_publicacao

    def consultar_titulo(self):
        return self.__titulo

    def consultar_autores(self):
        return self.__autores

    def consultar_ano_publicacao(self):
        return self.__ano_publicacao
    
    @abc.abstractmethod
    def imprimir_citacao(self):
        pass



class ArtigoConferencia(Artigo):

    def __init__(self, titulo, autores, ano_publicacao, local_evento):
        Artigo.__init__(self, titulo, autores, ano_publicacao)
        self.__local_evento = local_evento

    def imprimir_citacao(self):
        # T.ESCOVEDO, M.KALINOWSKI, Desbravando o Python nas Empresas, 2023, Maceió

        # variável que vai armazenar a lista de nomes citação de autores
        lista_de_autores = ""

        # para cada autor na lista de autores
        for autor in self.consultar_autores():
            # vou concatenando o nome citação deste autor na variável acima
            lista_de_autores += autor.consultar_nome_citacao()
            # e concateno também uma vírgula e um espaço
            lista_de_autores += ", "

        # Desafio para casa: quem quiser pode substituir a última vírgula por um ponto!

        return("[Artigo de Conferência] {}{}, {}, {}.".format(lista_de_autores, self.consultar_titulo(), self.consultar_ano_publicacao(), self.__local_evento))


class ArtigoPeriodico(Artigo):

    def __init__(self, titulo, autores, ano_publicacao, issn):
        Artigo.__init__(self, titulo, autores, ano_publicacao)
        self.__issn = issn

    def imprimir_citacao(self):
        # T.ESCOVEDO, M.KALINOWSKI, Desbravando o Python nas Empresas, 2023, 4592-9034

        # variável que vai armazenar a lista de nomes citação de autores
        lista_de_autores = ""

        # para cada autor na lista de autores
        for autor in self.consultar_autores():
            # vou concatenando o nome citação deste autor na variável acima
            lista_de_autores += autor.consultar_nome_citacao()
            # e concateno também uma vírgula e um espaço
            lista_de_autores += ", "

        # Desafio para casa: quem quiser pode substituir a última vírgula por um ponto!

        return("[Artigo de Periódico] {}{}, {}, {}.".format(lista_de_autores, self.consultar_titulo(), self.consultar_ano_publicacao(), self.__issn))


class BibliotecaArtigos:

    def __init__(self):
        self.__artigos = [] # a biblioteca ao ser criada virá com uma lista de artigos vazia

    def publicar_artigo(self, artigo):
        self.__artigos.append(artigo)

    def imprimir_catalogo_artigos(self):

        # Verificando se a lista de artigos está vazia
        if len(self.__artigos) == 0:
            print("\n### Não há artigos cadastrados na biblioteca!")
        else:
            # Apenas se a lista de artigos não for vazia
            print("\n### Artigos cadastrados na biblioteca:")
            for artigo in self.__artigos:
                print("-", artigo.imprimir_citacao())


    def encontrar_artigo_com_mais_autores(self):

        # Verificando se a lista de artigos está vazia
        if len(self.__artigos) == 0:
            print("\n### Não há artigos cadastrados na biblioteca!")
            return
        else:
            print("\n### Artigo com mais autores:")

            # definindo as variáveis para contabilização
            maior_qtd_autores = 0
            artigo_com_mais_autores = None

            # percorrendo a lista de artigos
            for artigo in self.__artigos:
                # contar o número de autores do artigo da vez
                qtd_autores = len(artigo.consultar_autores())
                # se qtd_autores for maior que a maior_qtd_autores até o momento, guardo o artigo da vez
                if qtd_autores > maior_qtd_autores:
                    maior_qtd_autores = qtd_autores
                    artigo_com_mais_autores = artigo

            # ao fim do loop, retorno o artigo com mais autores
            return artigo_com_mais_autores

    def encontrar_artigos_por_autor(self, autor):

        # Verificando se a lista de artigos está vazia
        if len(self.__artigos) == 0:
            print("\n### Não há artigos cadastrados na biblioteca!")
            return
        else:
            print("\n### Artigos do autor {}:".format(autor.consultar_nome_completo()))

            # lista de artigos do autor
            artigos_do_autor = []

            # percorrendo a lista de artigos
            for artigo in self.__artigos:
                # recupera a lista de autores do artigo
                lista_de_autores = artigo.consultar_autores()
                # verifica se o autor está na lista de autores
                if autor in lista_de_autores:
                    # se o autor está na lista, adiciona o artigo na lista de artigos
                    artigos_do_autor.append(artigo)

            return artigos_do_autor

# %%
# Instanciando a biblioteca
biblioteca = BibliotecaArtigos()

# Criando os autores
autor_1 = Autor("Tatiana Escovedo", "ESCOVEDO, T.", "PUC-Rio")
autor_2 = Autor("Marcos Kalinowski", "KALINOWSKI, M.", "PUC-Rio")
autor_3 = Autor("Sergio Lifschitz", "LIFSCHITZ, S.", "PUC-Rio")

# Criando os artigos
artigo_1 = ArtigoConferencia("Desbravando o Python nas Empresas", [autor_1, autor_2], 2023, "Maceió")
artigo_2 = ArtigoConferencia("Desbravando a Engenharia de Software nas Empresas", [autor_2], 2020, "Rio de Janeiro")
artigo_3 = ArtigoPeriodico("Desbravando o BD nas Empresas", [autor_3, autor_1], 2018, "2344-8778")

# Imprimindo o catálogo de artigos
biblioteca.imprimir_catalogo_artigos() # lista vazia!

# Publicando os artigos
biblioteca.publicar_artigo(artigo_1)
biblioteca.publicar_artigo(artigo_2)
biblioteca.publicar_artigo(artigo_3)

# Imprimindo o catálogo de artigos
biblioteca.imprimir_catalogo_artigos() # agora temos artigos na lista

# Artigo com mais autores - forma elegante!
artigo_com_mais_autores = biblioteca.encontrar_artigo_com_mais_autores()
if isinstance(artigo_com_mais_autores, Artigo):
    print(artigo_com_mais_autores.imprimir_citacao())

# if artigo_com_mais_autores is not None:

# Desafio para casa: quando tivermos mais um artigo com mais autores, como tratar? Dica: use uma lista

artigos_autor_1 = biblioteca.encontrar_artigos_por_autor(autor_1)
for artigo in artigos_autor_1:
    print(artigo.imprimir_citacao())

# Desafio para casa: em vez de procurar artigos do OBJETO autor, procurar pelo nome
# Desafio para casa mais legal ainda: possibilitar a busca por PARTE do nome
# Out:
# ### Não há artigos cadastrados na biblioteca!
#
# ### Artigos cadastrados na biblioteca:
# - [Artigo de Conferência] ESCOVEDO, T., KALINOWSKI, M., Desbravando o Python nas Empresas, 2023, Maceió.
# - [Artigo de Conferência] KALINOWSKI, M., Desbravando a Engenharia de Software nas Empresas, 2020, Rio de Janeiro.
# - [Artigo de Periódico] LIFSCHITZ, S., ESCOVEDO, T., Desbravando o BD nas Empresas, 2018, 2344-8778.
#
# ### Artigo com mais autores:
# [Artigo de Conferência] ESCOVEDO, T., KALINOWSKI, M., Desbravando o Python nas Empresas, 2023, Maceió.
#
# ### Artigos do autor Tatiana Escovedo:
# [Artigo de Conferência] ESCOVEDO, T., KALINOWSKI, M., Desbravando o Python nas Empresas, 2023, Maceió.
# [Artigo de Periódico] LIFSCHITZ, S., ESCOVEDO, T., Desbravando o BD nas Empresas, 2018, 2344-8778.

# %%
# Para casa: testar se funciona usar:
# max_obj = max(lista_obj, key=lambda obj: obj.valor)
